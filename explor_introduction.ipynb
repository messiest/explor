# %% [markdown]
# ## Using `xplor`

# %% [markdown]
# The core component of the `xplor` package is the class `EDA`.
# This notebook will provide a brief introduction to its use.

# %% [markdown]
# _Note: As of this writing, `xplor` is still in prerelease, and is not available to install using the `pip` utility. In order to follow along with this notebook._

# %% [markdown]
# ## Importing `EDA` from `xplor`
#
# The main, and as of right now, only, work horse in the `xplor` package is the `EDA` class.
# For this reason, we recommend simply importing `EDA` from `xplor`.

# %%
from explor import EDA

# %%
help(EDA)
# Out:
# Help on class EDA in module explor:
#
# class EDA(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self, data=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  analyze(self, plot=False)
#  |
#  |  analyze_df(self, df, plot=False)
#  |      :param df: Data to run data analysis on
#  |      :type df: pandas DataFrame
#  |      :return: None
#  |      :rtype: None
#  |
#  |  analyze_series(self, df, plot=False)
#  |      :param df: Data to run data analysis on
#  |      :type df: pandas DataFrame
#  |      :return: None
#  |      :rtype: None
#  |
#  |  corr_plot(self, adv=False)
#  |
#  |  get_data(self)
#  |
#  |  set_data(self, data)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# `EDA` is how you will perform the exploratory data analysis on your data.
#
# We'll begin by generating some "toy" data, using `numpy`, and `pandas`.

# %%
import numpy as np
import pandas as pd

data = np.random.randint(0, 100, 100)  # generate an array of 1000 random integers between 0 and 100
data = data.reshape(25, 4)  # change the shape of the array to 250 rows, and 4 columns
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])  # convert our data to a pandas DataFrame, and add column labels

# %% [markdown]
# Now, let's create an instance of `EDA`.

# %%
eda = EDA()

# %% [markdown]
# To load your dataframe, `df`, you use the method `.set_data()`.

# %%
eda.set_data(df)

# %% [markdown]
# To conduct exploratory data analysis, use the method, `.analyze()`.

# %%
# eda.analyze()

# %% [markdown]
# Excellent!
# You can now see some of the summary statistics for all of the features of your data, as well as some important values for each feature, such as the datatype, and the counts of unique values, and missing values.
# While this is useful, many may find it useful to _see_ their data.
# To do this, we use the `plot` parameter of the `.analyze()` method.

# %%
# %matplotlib inline

# eda.analyze(plot=True)

# %% [markdown]
# _Caution: At this time, the plot parameter had no limiting on it, so if your dataframe is incredibly large, it could take a long time to process the output._

# %% [markdown]
# `EDA` can also be used to handle individual `pandas Series`.
# Let's generate some toy data to illustrate this.

# %%
data = np.random.normal(0, 1, 1000)  # generate 1000 random observations from a standard normal distribution.

series = pd.Series(data)

series.name = "Normal Distribution"

# %%
eda.set_data(series)

eda.analyze(plot=True)
# Out:
# Series Name:
# -  Normal Distribution
# Data Type: float64
#
# Unique Values: 1000
#
# Missing Values: 0
#
# count    1000.000000
# mean       -0.047378
# std         1.024808
# min        -3.201284
# 25%        -0.740971
# 50%        -0.043095
# 75%         0.587377
# max         3.260211
# Name: Normal Distribution, dtype: float64
#
# Index eligible - All values of Normal Distribution are unique

# %% [markdown]
# This introduction will continue to be expanded on as `xplor` is extended.
#
# If there are any questions, or feature requests, please refer to the [GitHub repository](http://bit.ly/xplor-github).

# %%
data = np.random.randint(0, 100, 100)
data = data.reshape(20, 5)
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D', 'E'])

# %%
eda.set_data(df)

# %%
eda.corr_plot(adv=True);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
